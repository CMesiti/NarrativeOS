# %%
import numpy
import spacy
import chromadb

# %%
chroma_client = chromadb.Client()

#create a collection
collection = chroma_client.create_collection(name="rulebook")

#parse text into chunks and upload into document.

collection.add(
    id=[str(i) for i in range(chunks)],
    documents=[chunk for chunk in chunks])
